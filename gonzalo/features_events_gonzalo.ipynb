# %% [markdown]
# # Analisis de superficial del csv de events
# ### En este notebook exploramos los registros del csv con el objetivo de buscar relaciones entre las distintas variables

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Leemos el csv, y estalbecemos el tipo de dato de cada columna

# %%
events = pd.read_csv("../data/events.csv", dtype={'date': 'str', 'event_id': np.int16, 'ref_type': 'category',
                                               'ref_hash': 'int64', 'application_id':np.int16, 'attributed': 'bool',
                                               'device_countrycode': 'int64', 'device_os_version':'float64', 'device_brand': 'float64',
                                               'device_model': 'float64', 'device_city':'float64', 'session_user_agent': 'float64',
                                               'trans_id': 'str', 'user_agent':'float64', 'event_uuid': 'str',
                                               'carrier': 'float64', 'kind':'float64', 'device_os': 'category',
                                               'wifi': np.float16, 'connection_type':'str', 'ip_address': 'int64',
                                               'device_language': 'float64'}, parse_dates = ['date'])
events['day'] = events['date'].dt.date
events['hour'] = events['date'].dt.hour
events.head(5)
# Out:
#      index                    date  event_id             ref_type  \
# 0  2130678 2019-04-20 01:42:49.120         0  1891515180541284343
# 1  2130680 2019-04-20 01:42:49.340         1  1891515180541284343
# 2  2130681 2019-04-20 01:42:49.365         1  1891515180541284343
# 3  2130684 2019-04-20 01:42:51.438         2  1891515180541284343
# 4  2130688 2019-04-20 01:42:51.838         1  1891515180541284343
#
#               ref_hash  application_id  attributed   device_countrycode  \
# 0  5857744372586891366             210       False  6287817205707153877
# 1  7642521036780133571             210       False  6287817205707153877
# 2  2548841562898283198             210       False  6287817205707153877
# 3   609402887625919085             210       False  6287817205707153877
# 4  9114651763556439823             210       False  6287817205707153877
#
#    device_os_version  device_brand  ...                            event_uuid  \
# ...

# %%
events['device_countrycode'].value_counts()
# Out:
# 6287817205707153877    7744581
# Name: device_countrycode, dtype: int64

# %%
events['date'].max()
# Out:
# Timestamp('2019-04-26 23:59:59.881000')

# %%
events['date'].min()
# Out:
# Timestamp('2019-04-18 00:00:00.027000')

# %% [markdown]
# ## Revisamos el tipo de cada columna

# %%
events.dtypes
# Out:
# index                          int64
# date                  datetime64[ns]
# event_id                       int16
# ref_type                    category
# ref_hash                       int64
# application_id                 int16
# attributed                      bool
# device_countrycode             int64
# device_os_version            float64
# device_brand                 float64
# device_model                 float64
# device_city                  float64
# session_user_agent           float64
# trans_id                      object
# user_agent                   float64
# event_uuid                    object
# carrier                      float64
# kind                         float64
# device_os                   category
# wifi                         float16
# connection_type               object
# ip_address                     int64
# device_language              float64
# day                           object
# hour                           int64
# dtype: object

# %% [markdown]
# ## Elegimos las columnas con menor entropia o pocos valores diferentes y nos quedamos con los 5 valores mas comunes

# %%
grupos = ['event_id', 'ref_type','application_id', 'device_os', 'wifi', 'connection_type', 'hour', 'day', 'attributed']
top5 = {}
for i in grupos: 
    top5[i]= events[i].value_counts().head(5).index.tolist()
top5
# Out:
# {'application_id': [210, 122, 121, 65, 26],
#  'attributed': [False, True],
#  'connection_type': ['Cable/DSL', 'Cellular', 'Corporate', 'Dialup'],
#  'day': [datetime.date(2019, 4, 26),
#   datetime.date(2019, 4, 25),
#   datetime.date(2019, 4, 24),
#   datetime.date(2019, 4, 23),
#   datetime.date(2019, 4, 22)],
#  'device_os': ['7.531669329342818e+18', '6.941824626260379e+18'],
#  'event_id': [1, 15, 23, 2, 115],
#  'hour': [0, 2, 1, 23, 22],
#  'ref_type': ['1891515180541284343', '1494519392962156891'],
#  'wifi': [0.0, 1.0]}

# %%
events = events.sort_values(by = 'date')
events = events.sort_values(by = 'ref_hash')
events['repeticiones'] = 1
device_ids = events['ref_hash'].to_frame().set_index('ref_hash')
#events = pd.get_dummies(events, columns = grupos)
for column in grupos:
    for value in top5[column]:
        events[column + str(value)] = (events[column] == value)*1

# %%
fecha_minima=pd.to_datetime('2019-04-18 00:00:00')
fecha_minima
fecha_tope=pd.to_datetime('2019-04-21 00:00:00')
events_ventana1=events.loc[((events['date']>fecha_minima) & (events['date']<fecha_tope) )].copy(deep=False)

# %%
fecha_minima=pd.to_datetime('2019-04-19 00:00:00')
fecha_minima
fecha_tope=pd.to_datetime('2019-04-22 00:00:00')
events_ventana2=events.loc[((events['date']>fecha_minima) & (events['date']<fecha_tope) )].copy(deep=False)

# %%
fecha_minima=pd.to_datetime('2019-04-20 00:00:00')
fecha_minima
fecha_tope=pd.to_datetime('2019-04-23 00:00:00')
events_ventana3=events.loc[((events['date']>fecha_minima) & (events['date']<fecha_tope) )].copy(deep=False)

# %%
fecha_minima=pd.to_datetime('2019-04-21 00:00:00')
fecha_minima
fecha_tope=pd.to_datetime('2019-04-24 00:00:00')
events_ventana4=events.loc[((events['date']>fecha_minima) & (events['date']<fecha_tope) )].copy(deep=False)

# %%
fecha_minima=pd.to_datetime('2019-04-24 00:00:00')
fecha_minima
fecha_tope=pd.to_datetime('2019-04-27 00:00:00')
events_ventana7=events.loc[((events['date']>fecha_minima) & (events['date']<fecha_tope) )].copy(deep=False)

# %%
features = ['sum', 'mean', 'std', 'min', 'max']
ventanas = [events_ventana1, events_ventana2, events_ventana3, events_ventana4, events_ventana7]
numero_de_ventanas = [1,2,3,4,7]

# %%
drop_columns_sc = [
    'index_std',
    'event_id_sum',
    'event_id_mean',
    'event_id_std',
    'event_id_min',
    'event_id_max',
    'application_id_sum',
    'application_id_std',
    'application_id_min',
    'application_id_max',
    'attributed_sum',
    'attributed_mean',
    'attributed_std',
    'attributed_min',
    'attributed_max',
    'device_countrycode_sum',
    'device_countrycode_mean',
    'device_countrycode_std',
    'device_countrycode_min',
    'device_countrycode_max',
    'device_os_version_sum',
    'device_os_version_mean',
    'device_os_version_std',
    'device_os_version_min',
    'device_os_version_max',
    'device_brand_sum',
    'device_brand_mean',
    'device_brand_std',
    'device_brand_min',
    'device_brand_max',
    'device_model_sum',
    'device_model_mean',
    'device_model_min',
    'device_model_max',
    'device_city_sum',
    'device_city_mean',
    'device_city_std',
    'device_city_min',
    'device_city_max',
    'session_user_agent_sum',
    'session_user_agent_mean',
    'session_user_agent_std',
    'session_user_agent_min',
    'session_user_agent_max',
    'user_agent_sum',
    'user_agent_mean',
    'user_agent_std',
    'user_agent_min',
    'user_agent_max',
    'carrier_sum',
    'carrier_mean',
    'carrier_std',
    'carrier_min',
    'carrier_max',
    'kind_std',
    'kind_max',
    'wifi_sum',
    'wifi_mean',
    'wifi_std',
    'wifi_min',
    'wifi_max',
    'ip_address_std',
    'device_language_sum',
    'device_language_mean',
    'device_language_std',
    'device_language_min',
    'device_language_max',
    'hour_sum',
    'hour_mean',
    'hour_min',
    'hour_max',
    'repeticiones_sum',
    'repeticiones_mean',
    'repeticiones_std',
    'repeticiones_min',
    'repeticiones_max',
    'event_id1_sum',
    'event_id1_mean',
    'event_id1_std',
    'event_id1_min',
    'event_id1_max',
    'event_id15_sum',
    'event_id15_mean',
    'event_id15_std',
    'event_id15_min',
    'event_id15_max',
    'event_id23_sum',
    'event_id23_mean',
    'event_id23_std',
    'event_id23_min',
    'event_id23_max',
    'event_id2_sum',
    'event_id2_mean',
    'event_id2_std',
    'event_id2_min',
    'event_id2_max',
    'event_id115_sum',
    'event_id115_mean',
    'event_id115_std',
    'event_id115_min',
    'event_id115_max',
    'ref_type1891515180541284343_sum',
    'ref_type1891515180541284343_mean',
    'ref_type1891515180541284343_std',
    'ref_type1891515180541284343_min',
    'ref_type1891515180541284343_max',
    'ref_type1494519392962156891_sum',
    'ref_type1494519392962156891_mean',
    'ref_type1494519392962156891_std',
    'ref_type1494519392962156891_min',
    'ref_type1494519392962156891_max',
    'application_id210_sum',
    'application_id210_mean',
    'application_id210_std',
    'application_id210_min',
    'application_id210_max',
    'application_id122_sum',
    'application_id122_mean',
    'application_id122_std',
    'application_id122_min',
    'application_id122_max',
    'application_id121_sum',
    'application_id121_mean',
    'application_id121_std',
    'application_id121_min',
    'application_id121_max',
    'application_id65_sum',
    'application_id65_mean',
    'application_id65_std',
    'application_id65_min',
    'application_id65_max',
    'application_id26_sum',
    'application_id26_mean',
    'application_id26_std',
    'application_id26_min',
    'application_id26_max',
    'device_os7.531669329342818e+18_sum',
    'device_os7.531669329342818e+18_mean',
    'device_os7.531669329342818e+18_std',
    'device_os7.531669329342818e+18_min',
    'device_os7.531669329342818e+18_max',
    'device_os6.941824626260379e+18_sum',
    'device_os6.941824626260379e+18_mean',
    'device_os6.941824626260379e+18_std',
    'device_os6.941824626260379e+18_min',
    'device_os6.941824626260379e+18_max',
    'wifi0.0_sum',
    'wifi0.0_mean',
    'wifi0.0_std',
    'wifi0.0_min',
    'wifi0.0_max',
    'wifi1.0_sum',
    'wifi1.0_mean',
    'wifi1.0_std',
    'wifi1.0_min',
    'wifi1.0_max',
    'connection_typeCable/DSL_sum',
    'connection_typeCable/DSL_mean',
    'connection_typeCable/DSL_std',
    'connection_typeCable/DSL_min',
    'connection_typeCable/DSL_max',
    'connection_typeCellular_sum',
    'connection_typeCellular_mean',
    'connection_typeCellular_std',
    'connection_typeCellular_min',
    'connection_typeCellular_max',
    'connection_typeCorporate_sum',
    'connection_typeCorporate_mean',
    'connection_typeCorporate_std',
    'connection_typeCorporate_min',
    'connection_typeCorporate_max',
    'connection_typeDialup_sum',
    'connection_typeDialup_mean',
    'connection_typeDialup_std',
    'connection_typeDialup_min',
    'connection_typeDialup_max',
    'hour0_sum',
    'hour0_mean',
    'hour0_std',
    'hour0_min',
    'hour0_max',
    'hour2_sum',
    'hour2_mean',
    'hour2_std',
    'hour2_min',
    'hour2_max',
    'hour1_sum',
    'hour1_mean',
    'hour1_std',
    'hour1_min',
    'hour1_max',
    'hour23_sum',
    'hour23_mean',
    'hour23_std',
    'hour23_min',
    'hour23_max',
    'hour22_sum',
    'hour22_mean',
    'hour22_std',
    'hour22_min',
    'hour22_max',
    'day2019-04-26_sum',
    'day2019-04-26_mean',
    'day2019-04-26_std',
    'day2019-04-26_min',
    'day2019-04-26_max',
    'day2019-04-25_sum',
    'day2019-04-25_mean',
    'day2019-04-25_std',
    'day2019-04-25_min',
    'day2019-04-25_max',
    'day2019-04-24_sum',
    'day2019-04-24_mean',
    'day2019-04-24_std',
    'day2019-04-24_min',
    'day2019-04-24_max',
    'day2019-04-23_sum',
    'day2019-04-23_mean',
    'day2019-04-23_std',
    'day2019-04-23_min',
    'day2019-04-23_max',
    'day2019-04-22_sum',
    'day2019-04-22_mean',
    'day2019-04-22_std',
    'day2019-04-22_min',
    'day2019-04-22_max',
    'attributedFalse_sum',
    'attributedFalse_mean',
    'attributedFalse_std',
    'attributedFalse_min',
    'attributedFalse_max',
    'attributedTrue_sum',
    'attributedTrue_mean',
    'attributedTrue_std',
    'attributedTrue_min',
    'attributedTrue_max']

# %%
drop_columns_st = [
    'index_sum',
    'index_mean',
    'index_std',
    'index_min',
    'index_max',
    'event_id_sum',
    'event_id_mean',
    'event_id_std',
    'event_id_min',
    'event_id_max',
    'application_id_sum',
    'application_id_std',
    'application_id_min',
    'application_id_max',
    'attributed_sum',
    'attributed_mean',
    'attributed_std',
    'attributed_min',
    'attributed_max',
    'device_countrycode_sum',
    'device_countrycode_mean',
    'device_countrycode_std',
    'device_countrycode_min',
    'device_countrycode_max',
    'device_os_version_sum',
    'device_os_version_mean',
    'device_os_version_std',
    'device_os_version_min',
    'device_os_version_max',
    'device_brand_sum',
    'device_brand_mean',
    'device_brand_std',
    'device_brand_min',
    'device_brand_max',
    'device_model_sum',
    'device_model_mean',
    'device_model_std',
    'device_model_min',
    'device_model_max',
    'device_city_sum',
    'device_city_mean',
    'device_city_std',
    'device_city_min',
    'device_city_max',
    'session_user_agent_sum',
    'session_user_agent_mean',
    'session_user_agent_std',
    'session_user_agent_min',
    'session_user_agent_max',
    'user_agent_sum',
    'user_agent_mean',
    'user_agent_std',
    'user_agent_min',
    'user_agent_max',
    'carrier_sum',
    'carrier_mean',
    'carrier_std',
    'carrier_min',
    'carrier_max',
    'kind_sum',
    'kind_std',
    'kind_max',
    'wifi_sum',
    'wifi_mean',
    'wifi_std',
    'wifi_min',
    'wifi_max',
    'ip_address_sum',
    'ip_address_mean',
    'ip_address_std',
    'ip_address_min',
    'ip_address_max',
    'device_language_sum',
    'device_language_mean',
    'device_language_std',
    'device_language_min',
    'device_language_max',
    'hour_sum',
    'hour_mean',
    'hour_std',
    'hour_min',
    'hour_max',
    'repeticiones_sum',
    'repeticiones_mean',
    'repeticiones_std',
    'repeticiones_min',
    'repeticiones_max',
    'event_id1_sum',
    'event_id1_mean',
    'event_id1_std',
    'event_id1_min',
    'event_id1_max',
    'event_id15_sum',
    'event_id15_mean',
    'event_id15_std',
    'event_id15_min',
    'event_id15_max',
    'event_id23_sum',
    'event_id23_mean',
    'event_id23_std',
    'event_id23_min',
    'event_id23_max',
    'event_id2_sum',
    'event_id2_mean',
    'event_id2_std',
    'event_id2_min',
    'event_id2_max',
    'event_id115_sum',
    'event_id115_mean',
    'event_id115_std',
    'event_id115_min',
    'event_id115_max',
    'ref_type1891515180541284343_sum',
    'ref_type1891515180541284343_mean',
    'ref_type1891515180541284343_std',
    'ref_type1891515180541284343_min',
    'ref_type1891515180541284343_max',
    'ref_type1494519392962156891_sum',
    'ref_type1494519392962156891_mean',
    'ref_type1494519392962156891_std',
    'ref_type1494519392962156891_min',
    'ref_type1494519392962156891_max',
    'application_id210_sum',
    'application_id210_mean',
    'application_id210_std',
    'application_id210_min',
    'application_id210_max',
    'application_id122_sum',
    'application_id122_mean',
    'application_id122_std',
    'application_id122_min',
    'application_id122_max',
    'application_id121_sum',
    'application_id121_mean',
    'application_id121_std',
    'application_id121_min',
    'application_id121_max',
    'application_id65_sum',
    'application_id65_mean',
    'application_id65_std',
    'application_id65_min',
    'application_id65_max',
    'application_id26_sum',
    'application_id26_mean',
    'application_id26_std',
    'application_id26_min',
    'application_id26_max',
    'device_os7.531669329342818e+18_sum',
    'device_os7.531669329342818e+18_mean',
    'device_os7.531669329342818e+18_std',
    'device_os7.531669329342818e+18_min',
    'device_os7.531669329342818e+18_max',
    'device_os6.941824626260379e+18_sum',
    'device_os6.941824626260379e+18_mean',
    'device_os6.941824626260379e+18_std',
    'device_os6.941824626260379e+18_min',
    'device_os6.941824626260379e+18_max',
    'wifi0.0_sum',
    'wifi0.0_mean',
    'wifi0.0_std',
    'wifi0.0_min',
    'wifi0.0_max',
    'wifi1.0_sum',
    'wifi1.0_mean',
    'wifi1.0_std',
    'wifi1.0_min',
    'wifi1.0_max',
    'connection_typeCable/DSL_sum',
    'connection_typeCable/DSL_mean',
    'connection_typeCable/DSL_std',
    'connection_typeCable/DSL_min',
    'connection_typeCable/DSL_max',
    'connection_typeCellular_sum',
    'connection_typeCellular_mean',
    'connection_typeCellular_std',
    'connection_typeCellular_min',
    'connection_typeCellular_max',
    'connection_typeCorporate_sum',
    'connection_typeCorporate_mean',
    'connection_typeCorporate_std',
    'connection_typeCorporate_min',
    'connection_typeCorporate_max',
    'connection_typeDialup_sum',
    'connection_typeDialup_mean',
    'connection_typeDialup_std',
    'connection_typeDialup_min',
    'connection_typeDialup_max',
    'hour0_sum',
    'hour0_mean',
    'hour0_std',
    'hour0_min',
    'hour0_max',
    'hour2_sum',
    'hour2_mean',
    'hour2_std',
    'hour2_min',
    'hour2_max',
    'hour1_sum',
    'hour1_mean',
    'hour1_std',
    'hour1_min',
    'hour1_max',
    'hour23_sum',
    'hour23_mean',
    'hour23_std',
    'hour23_min',
    'hour23_max',
    'hour22_sum',
    'hour22_std',
    'hour22_min',
    'hour22_max',
    'day2019-04-26_sum',
    'day2019-04-26_mean',
    'day2019-04-26_std',
    'day2019-04-26_min',
    'day2019-04-26_max',
    'day2019-04-25_sum',
    'day2019-04-25_mean',
    'day2019-04-25_std',
    'day2019-04-25_min',
    'day2019-04-25_max',
    'day2019-04-24_sum',
    'day2019-04-24_mean',
    'day2019-04-24_std',
    'day2019-04-24_min',
    'day2019-04-24_max',
    'day2019-04-23_sum',
    'day2019-04-23_mean',
    'day2019-04-23_std',
    'day2019-04-23_min',
    'day2019-04-23_max',
    'day2019-04-22_sum',
    'day2019-04-22_mean',
    'day2019-04-22_std',
    'day2019-04-22_min',
    'day2019-04-22_max',
    'attributedFalse_sum',
    'attributedFalse_mean',
    'attributedFalse_std',
    'attributedFalse_min',
    'attributedFalse_max',
    'attributedTrue_sum',
    'attributedTrue_mean',
    'attributedTrue_std',
    'attributedTrue_min',
    'attributedTrue_max']

# %%
contador = 0
for ventana in ventanas:
    features_ventana = ventana.groupby('ref_hash').agg(features).fillna(0)
    level0 = features_ventana.columns.get_level_values(0)
    level1 = features_ventana.columns.get_level_values(1)
    features_ventana.columns = level0 + "_" + level1
    features_st = features_ventana.drop(drop_columns_st, axis=1, inplace = False)
    features_st.to_csv('../xgb/features_events_gonzalo_st_ventana' + str(numero_de_ventanas[contador]) + '.csv')
    features_sc = features_ventana.drop(drop_columns_sc, axis=1, inplace = False)
    features_sc.to_csv('../xgb/features_events_gonzalo_sc_ventana' + str(numero_de_ventanas[contador]) + '.csv')
    contador = contador + 1
